# %% [markdown]
# # Lab 1B: Get the Picture?
#
# ---

# %%
import pandas as pd
import seaborn as sns #this is another library we'll use

# %%
#load the data and assign it to the variable cdc
cdc = pd.read_csv("https://raw.githubusercontent.com/nschettini/datasets/master/cdc.csv")

# %%
cdc
# Out:
#        Unnamed: 0           age  ...              drink_water sunburns
# 0               1  16 years old  ...           1 time per day  0 times
# 1               2  16 years old  ...          2 times per day  0 times
# 2               3  17 years old  ...  4 or more times per day  2 times
# 3               4  17 years old  ...           1 time per day  0 times
# 4               5  16 years old  ...  4 or more times per day  1 times
# ...           ...           ...  ...                      ...      ...
# 15619       15620  15 years old  ...                      NaN      NaN
# 15620       15621  15 years old  ...                      NaN      NaN
# 15621       15622  17 years old  ...                      NaN      NaN
# 15622       15623  15 years old  ...                      NaN      NaN
# 15623       15624  15 years old  ...                      NaN      NaN
#
# [15624 rows x 34 columns]

# %%
len(cdc.columns)
# Out:
# 34

# %%
list(cdc)
# Out:
# ['Unnamed: 0',
#  'age',
#  'gender',
#  'grade',
#  'hisp_latino',
#  'race',
#  'height',
#  'weight',
#  'helmet',
#  'seat_belt',
#  'drive_text',
#  'fights',
#  'bully_school',
#  'bully_electronic',
#  'depressed',
#  'days_smoking',
#  'days_vaping',
#  'sexuality',
#  'describe_weight',
#  'drink_juice',
#  'eat_fruit',
#  'eat_salad',
#  'drink_soda',
#  'drink_milk',
#  'eat_breakfast',
#  'days_exercise_60',
#  'hours_tv',
#  'hours_videogame',
#  'number_teams',
#  'asthma',
#  'hours_sleep',
#  'drink_sportsdrink',
#  'drink_water',
#  'sunburns']

# %%
cdc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15624 entries, 0 to 15623
# Data columns (total 34 columns):
# Unnamed: 0           15624 non-null int64
# age                  15558 non-null object
# gender               15506 non-null object
# grade                15507 non-null object
# hisp_latino          15379 non-null object
# race                 15266 non-null object
# height               14358 non-null float64
# weight               14358 non-null float64
# helmet               13162 non-null object
# seat_belt            14070 non-null object
# drive_text           14657 non-null object
# fights               13124 non-null object
# bully_school         15448 non-null object
# bully_electronic     15465 non-null object
# depressed            15455 non-null object
# days_smoking         14989 non-null object
# days_vaping          15318 non-null object
# sexuality            14703 non-null object
# describe_weight      15320 non-null object
# ...

# %%
cdc.plot(kind="hist", y="height")

# %%
cdc['height'].value_counts().plot.bar()

# %%
cdc.plot(kind="hist", y="race")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-a0da1452a873> in <module>()
# ----> 1 cdc.plot(kind="hist", y="race")
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
# ...

# %%
cdc['race'].value_counts().plot.bar()

# %%
cdc['drive_text'].value_counts().plot.bar()

# %%
sns.countplot(y="drive_text", hue="gender", data=cdc)

# %%
sns.pairplot(cdc, hue="gender")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
cdc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15624 entries, 0 to 15623
# Data columns (total 34 columns):
# Unnamed: 0           15624 non-null int64
# age                  15558 non-null object
# gender               15506 non-null object
# grade                15507 non-null object
# hisp_latino          15379 non-null object
# race                 15266 non-null object
# height               14358 non-null float64
# weight               14358 non-null float64
# helmet               13162 non-null object
# seat_belt            14070 non-null object
# drive_text           14657 non-null object
# fights               13124 non-null object
# bully_school         15448 non-null object
# bully_electronic     15465 non-null object
# depressed            15455 non-null object
# days_smoking         14989 non-null object
# days_vaping          15318 non-null object
# sexuality            14703 non-null object
# describe_weight      15320 non-null object
# ...
